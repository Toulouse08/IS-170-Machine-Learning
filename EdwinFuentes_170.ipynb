# %% [markdown]
# <a href="https://colab.research.google.com/github/Toulouse08/IS-170-Machine-Learning/blob/K-Nearest-Neighbors/EdwinFuentes_170.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Loan_Default.csv')
df
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0        24890  2019         cf  Sex Not Available         nopre     type1
# 1        24891  2019         cf               Male         nopre     type2
# 2        24892  2019         cf               Male           pre     type1
# 3        24893  2019         cf               Male         nopre     type1
# 4        24894  2019         cf              Joint           pre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
# ...

# %%
df.head()
# Out:
#       ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0  24890  2019         cf  Sex Not Available         nopre     type1
# 1  24891  2019         cf               Male         nopre     type2
# 2  24892  2019         cf               Male           pre     type1
# 3  24893  2019         cf               Male         nopre     type1
# 4  24894  2019         cf              Joint           pre     type1
#
#   loan_purpose Credit_Worthiness open_credit business_or_commercial  ...  \
# 0           p1                l1        nopc                  nob/c  ...
# 1           p1                l1        nopc                    b/c  ...
# 2           p1                l1        nopc                  nob/c  ...
# 3           p4                l1        nopc                  nob/c  ...
# 4           p1                l1        nopc                  nob/c  ...
#
#    credit_type  Credit_Score  co-applicant_credit_type    age  \
# ...

# %%
df.shape
# Out:
# (148670, 34)

# %%
pd.set_option("display.max_columns", df.shape[-1])
df.head(5)
# Out:
#       ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0  24890  2019         cf  Sex Not Available         nopre     type1
# 1  24891  2019         cf               Male         nopre     type2
# 2  24892  2019         cf               Male           pre     type1
# 3  24893  2019         cf               Male         nopre     type1
# 4  24894  2019         cf              Joint           pre     type1
#
#   loan_purpose Credit_Worthiness open_credit business_or_commercial  \
# 0           p1                l1        nopc                  nob/c
# 1           p1                l1        nopc                    b/c
# 2           p1                l1        nopc                  nob/c
# 3           p4                l1        nopc                  nob/c
# 4           p1                l1        nopc                  nob/c
#
#    loan_amount  rate_of_interest  Interest_rate_spread  Upfront_charges  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'year', 'loan_limit', 'Gender', 'approv_in_adv', 'loan_type',
#        'loan_purpose', 'Credit_Worthiness', 'open_credit',
#        'business_or_commercial', 'loan_amount', 'rate_of_interest',
#        'Interest_rate_spread', 'Upfront_charges', 'term', 'Neg_ammortization',
#        'interest_only', 'lump_sum_payment', 'property_value',
#        'construction_type', 'occupancy_type', 'Secured_by', 'total_units',
#        'income', 'credit_type', 'Credit_Score', 'co-applicant_credit_type',
#        'age', 'submission_of_application', 'LTV', 'Region', 'Security_Type',
#        'Status', 'dtir1'],
#       dtype='object')

# %%
df.columns= df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['id', 'year', 'loan_limit', 'gender', 'approv_in_adv', 'loan_type',
#        'loan_purpose', 'credit_worthiness', 'open_credit',
#        'business_or_commercial', 'loan_amount', 'rate_of_interest',
#        'interest_rate_spread', 'upfront_charges', 'term', 'neg_ammortization',
#        'interest_only', 'lump_sum_payment', 'property_value',
#        'construction_type', 'occupancy_type', 'secured_by', 'total_units',
#        'income', 'credit_type', 'credit_score', 'co-applicant_credit_type',
#        'age', 'submission_of_application', 'ltv', 'region', 'security_type',
#        'status', 'dtir1'],
#       dtype='object')

# %%
columns= ['id', 'year', 'loan_limit', 'gender', 'approv_in_adv', 'loan_purpose', 'credit_worthiness', 'open_credit', 'business_or_commercial', 'interest_rate_spread', 'upfront_charges', 'neg_ammortization', 'interest_only', 'lump_sum_payment', 'construction_type', 'secured_by', 'total_units', 'credit_type', 'co-applicant_credit_type', 'submission_of_application', 'ltv', 'region', 'security_type']
df.drop(columns, axis=1, inplace= True)

# %%
df.columns
# Out:
# Index(['loan_type', 'loan_amount', 'rate_of_interest', 'term',
#        'property_value', 'occupancy_type', 'income', 'credit_score', 'age',
#        'status', 'dtir1'],
#       dtype='object')

# %%
df.shape
# Out:
# (148670, 11)

# %%
print(df.isnull().sum())
# Out:
# loan_type               0
# loan_amount             0
# rate_of_interest    36439
# term                   41
# property_value      15098
# occupancy_type          0
# income               9150
# credit_score            0
# age                   200
# status                  0
# dtir1               24121
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of        loan_type  loan_amount  rate_of_interest   term  property_value  \
# 0          type1       116500               NaN  360.0        118000.0
# 1          type2       206500               NaN  360.0             NaN
# 2          type1       406500             4.560  360.0        508000.0
# 3          type1       456500             4.250  360.0        658000.0
# 4          type1       696500             4.000  360.0        758000.0
# ...          ...          ...               ...    ...             ...
# 148665     type1       436500             3.125  180.0        608000.0
# 148666     type1       586500             5.190  360.0        788000.0
# 148667     type1       446500             3.125  180.0        728000.0
# 148668     type1       196500             3.500  180.0        278000.0
# 148669     type1       406500             4.375  240.0        558000.0
#
#        occupancy_type   income  credit_score    age  status  dtir1
# ...

# %%
df.fillna(value=0, inplace=True)
df
# Out:
#        loan_type  loan_amount  rate_of_interest   term  property_value  \
# 0          type1       116500             0.000  360.0        118000.0
# 1          type2       206500             0.000  360.0             0.0
# 2          type1       406500             4.560  360.0        508000.0
# 3          type1       456500             4.250  360.0        658000.0
# 4          type1       696500             4.000  360.0        758000.0
# ...          ...          ...               ...    ...             ...
# 148665     type1       436500             3.125  180.0        608000.0
# 148666     type1       586500             5.190  360.0        788000.0
# 148667     type1       446500             3.125  180.0        728000.0
# 148668     type1       196500             3.500  180.0        278000.0
# 148669     type1       406500             4.375  240.0        558000.0
#
#        occupancy_type   income  credit_score    age  status  dtir1
# ...

# %%
print(df.isnull().sum())
# Out:
# loan_type           0
# loan_amount         0
# rate_of_interest    0
# term                0
# property_value      0
# occupancy_type      0
# income              0
# credit_score        0
# age                 0
# status              0
# dtir1               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['loan_type', 'loan_amount', 'rate_of_interest', 'term',
#        'property_value', 'occupancy_type', 'income', 'credit_score', 'age',
#        'status', 'dtir1'],
#       dtype='object')

# %%
df['loan_type'].max()
# Out:
# 'type3'

# %%
df['loan_type'].min()
# Out:
# 'type1'

# %%
df['loan_amount'].max()
# Out:
# 3576500

# %%
df['loan_amount'].min()
# Out:
# 16500

# %%
df['rate_of_interest'].max()
# Out:
# 8.0

# %%
df['rate_of_interest'].min()
# Out:
# 0.0

# %%
df['age'].value_counts()
# Out:
# 45-54    34720
# 35-44    32818
# 55-64    32534
# 65-74    20744
# 25-34    19142
# >74       7175
# <25       1337
# 0          200
# Name: age, dtype: int64

# %% [markdown]
# From this data we can see that there is a wide array of loan amounts and rates of interest. We can see that the majority of custoemrs are between the ages of 35-64, this is to show the average age of the cusotmer. We can also see that there is less demand to lend to those younger than 25 and older than 75 as they are of higher risk.
